# %%
import skimage

# %%
from skimage import data,io
import numpy as np

# %%
img=data.coffee()

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
io.imsave(fname='coffee.jpg', arr=img)

# %%
img = io.imread('coffee.jpg')

# %%
img=skimage.color.rgb2gray(img)

# %%
plt.imshow(img)

# %%
plt.show()

# %%
img=io.imread_collection('*.jpg')

# %%
plt.imshow(img[0])
plt.show()

# %%
img=img[0]

# %%
img.shape
# Out:
# (400, 600, 3)

# %%
img=skimage.util.crop(img,((50,50),(100,100),(0,0)))

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (300, 400, 3)

# %%
from skimage.transform import rescale

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img=rescale(img,0.5)

# %%
img.dtype
# Out:
# dtype('float64')

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (200, 300, 3, 3)

# %%
from skimage import util
img=img[:,:,:,1]
plt.imshow(img)
plt.show()

# %%
img=data.coffee()
img.max(),img.min()
# Out:
# (255, 0)

# %%
img=data.coffee()
img.max()
img=skimage.exposure.rescale_intensity(img)
img.max()
# Out:
# 255

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# # Image Segmentation

# %%
coins = data.coins()

# %%
hist = np.histogram(coins,bins=np.arange(0,256))

# %%
hist
# Out:
# (array([   0,    1,    2,    7,   10,    7,   10,   27,   16,   14,   17,
#           13,   13,   19,   13,   18,   29,   48,   68,   96,  120,  173,
#          239,  319,  446,  556,  640,  756,  786,  877,  965, 1069, 1061,
#         1149, 1186, 1147, 1264, 1195, 1160, 1179, 1142, 1197, 1154, 1163,
#         1089, 1085, 1100, 1061, 1026, 1110, 1028, 1022, 1031,  970, 1003,
#         1023,  971,  956,  988,  901,  938,  853,  850,  839,  789,  846,
#          805,  829,  828,  847,  857,  822,  769,  790,  716,  705,  695,
#          664,  664,  621,  600,  658,  702,  658,  686,  707,  746,  781,
#          743,  747,  718,  743,  735,  667,  697,  667,  570,  572,  536,
#          563,  530,  500,  555,  566,  550,  561,  511,  504,  519,  521,
#          508,  478,  480,  488,  541,  557,  530,  519,  520,  570,  550,
#          524,  569,  588,  556,  532,  534,  564,  550,  567,  558,  508,
#          479,  444,  468,  416,  423,  385,  410,  450,  420,  460,  422,
# ...

# %%
# detect edge
edges = skimage.feature.canny(coins/255.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-4f321622dad6> in <module>()
#       1 # detect edge
# ----> 2 edges = skimage.feature.canny(coins/255.)
#
# AttributeError: module 'skimage' has no attribute 'feature'
